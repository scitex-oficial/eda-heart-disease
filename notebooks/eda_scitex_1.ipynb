# %% [markdown]
# <div style="background: linear-gradient(135deg, #27295a 0%, #304b9a 100%);
#             padding: 40px 48px 32px 48px;
#             border-radius: 12px;
#             margin-bottom: 8px;">
#
#   <div style="margin-bottom: 16px;">
#     <div style="color: #85B7EB; font-size: 11px; font-weight: 600;
#                 letter-spacing: 3px; font-family: sans-serif;">
#       SCITEX · ANÁLISIS EXPLORATORIO DE DATOS
#     </div>
#     <div style="color: white; font-size: 26px; font-weight: 800;
#                 font-family: sans-serif; margin-top: 6px;">
#       Heart Disease UCI
#     </div>
#   </div>
#
#   <div style="color: rgba(255,255,255,0.75); font-size: 14px;
#               font-family: sans-serif; line-height: 1.6; margin-bottom: 20px;">
#     Análisis exploratorio de las variables clínicas que discriminan entre
#     pacientes con y sin enfermedad cardíaca. Dataset Cleveland · n=303.
#   </div>
#
#   <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#     <span style="background: rgba(60,120,187,0.3); color: #85B7EB;
#                  padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                  font-family: sans-serif; font-weight: 600;">Python</span>
#     <span style="background: rgba(60,120,187,0.3); color: #85B7EB;
#                  padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                  font-family: sans-serif; font-weight: 600;">Seaborn</span>
#     <span style="background: rgba(60,120,187,0.3); color: #85B7EB;
#                  padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                  font-family: sans-serif; font-weight: 600;">Matplotlib</span>
#     <span style="background: rgba(60,120,187,0.3); color: #85B7EB;
#                  padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                  font-family: sans-serif; font-weight: 600;">UCI Repository</span>
#     <span style="background: rgba(15,110,86,0.3); color: #5DCAA5;
#                  padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                  font-family: sans-serif; font-weight: 600;">#PensarConDatos</span>
#   </div>
#
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;">
#   <strong style="color: #27295a;">Autor:</strong> Manuel Merino &nbsp;·&nbsp;
#   <strong style="color: #27295a;">Fuente:</strong>
#   <a href="https://archive.ics.uci.edu/dataset/45/heart+disease"
#      style="color: #3c78bb;">UCI Machine Learning Repository</a> &nbsp;·&nbsp;
#   <strong style="color: #27295a;">LinkedIn:</strong>
#   <a href="https://www.linkedin.com/company/scitexoficial"
#      style="color: #3c78bb;">SciTeX</a>
# </div>

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">01</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">Importar librerías</div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("✓ Librerías cargadas correctamente")
print(f"  pandas     {pd.__version__}")
print(f"  seaborn    {sns.__version__}")
print(f"  matplotlib {plt.matplotlib.__version__}")
# Out:
# ✓ Librerías cargadas correctamente
#   pandas     2.3.3
#   seaborn    0.13.2
#   matplotlib 3.10.7

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">02</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">Cargar dataset</div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# > **Fuente:** UCI Machine Learning Repository · Heart Disease (Cleveland) · id=45

# %%
from ucimlrepo import fetch_ucirepo

heart = fetch_ucirepo(id=45)
X = heart.data.features
y = heart.data.targets

df = pd.concat([X, y], axis=1)
df['target'] = (df['num'] > 0).astype(int)
df = df.drop(columns='num')

print(f"✓ Dataset cargado: {df.shape[0]} filas · {df.shape[1]} columnas")
print(f"  Sin enfermedad : {(df['target']==0).sum()} pacientes")
print(f"  Con enfermedad : {(df['target']==1).sum()} pacientes")
print(f"  Valores nulos  :\n{df.isnull().sum()[df.isnull().sum()>0]}")
# Out:
# ✓ Dataset cargado: 303 filas · 14 columnas
#   Sin enfermedad : 164 pacientes
#   Con enfermedad : 139 pacientes
#   Valores nulos  :
# ca      4
# thal    2
# dtype: int64

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">03</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">Configuración de estilo</div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>

# %%
# ── Paleta SciTeX ──────────────────────────────────────────────────────────────
COLOR_NAVY   = '#27295a'
COLOR_ACCENT = '#3c78bb'
COLOR_GRAY   = '#71706f'
COLOR_BG     = '#f8f9fb'
COLOR_RED    = '#993C1D'

# ── Configuración global ───────────────────────────────────────────────────────
sns.set_theme(style='whitegrid', font='DejaVu Sans')
plt.rcParams.update({
    'axes.facecolor':    COLOR_BG,
    'figure.facecolor':  COLOR_BG,
    'axes.edgecolor':    '#ccccdd',
    'axes.labelcolor':   COLOR_NAVY,
    'xtick.color':       COLOR_GRAY,
    'ytick.color':       COLOR_GRAY,
    'axes.spines.top':   False,
    'axes.spines.right': False,
    'grid.color':        '#e0e0ec',
    'grid.linewidth':    0.6,
    'svg.fonttype':      'none',
})

# ── Preparar data ──────────────────────────────────────────────────────────────
target_map = {0: 'Sin enfermedad', 1: 'Con enfermedad'}
df['target_label'] = df['target'].map(target_map)

VAR   = 'thalach'
LABEL = 'Frecuencia Cardíaca Máxima (lpm)'

n_sin   = df[df['target_label'] == 'Sin enfermedad'].shape[0]
n_con   = df[df['target_label'] == 'Con enfermedad'].shape[0]
med_sin = df[df['target_label'] == 'Sin enfermedad'][VAR].median()
med_con = df[df['target_label'] == 'Con enfermedad'][VAR].median()

print(f"✓ Configuración aplicada")
print(f"  Sin enfermedad → n={n_sin} · mediana={med_sin:.0f} lpm")
print(f"  Con enfermedad → n={n_con} · mediana={med_con:.0f} lpm")
print(f"  Diferencia de medianas: {med_sin - med_con:.0f} lpm")
# Out:
# ✓ Configuración aplicada
#   Sin enfermedad → n=164 · mediana=161 lpm
#   Con enfermedad → n=139 · mediana=142 lpm
#   Diferencia de medianas: 19 lpm

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">04</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Estadísticas descriptivas
#     </div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>

# %%
resumen = df.groupby('target_label')[VAR].agg(
    n='count',
    media='mean',
    mediana='median',
    desv_std='std',
    minimo='min',
    maximo='max'
).round(1)

resumen.index.name = 'Diagnóstico'
resumen.columns = ['N', 'Media', 'Mediana', 'Desv. Std', 'Mínimo', 'Máximo']

resumen.style\
    .set_caption('Frecuencia Cardíaca Máxima (lpm) por Diagnóstico')\
    .set_table_styles([
        {'selector': 'caption',
         'props': [('font-size', '13px'), ('font-weight', 'bold'),
                   ('color', '#27295a'), ('padding-bottom', '8px')]},
        {'selector': 'th',
         'props': [('background-color', '#27295a'), ('color', 'white'),
                   ('font-size', '12px'), ('padding', '8px 14px')]},
        {'selector': 'td',
         'props': [('font-size', '12px'), ('padding', '6px 14px'),
                   ('color', '#27295a')]},
        {'selector': 'tr:nth-child(even)',
         'props': [('background-color', '#f0f0f8')]},
        {'selector': 'tr:hover',
         'props': [('background-color', '#e0e8f5')]},
    ])\
    .highlight_max(color='#d4edda')\
    .highlight_min(color='#f8d7da')
# Out:
# <style type="text/css">
# #T_1ea73 caption {
#   font-size: 13px;
#   font-weight: bold;
#   color: #27295a;
#   padding-bottom: 8px;
# }
# #T_1ea73 th {
#   background-color: #27295a;
#   color: white;
#   font-size: 12px;
#   padding: 8px 14px;
# }
# #T_1ea73 td {
#   font-size: 12px;
#   padding: 6px 14px;
#   color: #27295a;
# }
# #T_1ea73 tr:nth-child(even) {
#   background-color: #f0f0f8;
# }
# #T_1ea73 tr:hover {
#   background-color: #e0e8f5;
# }
# #T_1ea73_row0_col0, #T_1ea73_row0_col1, #T_1ea73_row0_col2, #T_1ea73_row0_col4, #T_1ea73_row0_col5, #T_1ea73_row1_col3 {
#   background-color: #f8d7da;
# }
# #T_1ea73_row0_col3, #T_1ea73_row1_col0, #T_1ea73_row1_col1, #T_1ea73_row1_col2, #T_1ea73_row1_col4, #T_1ea73_row1_col5 {
#   background-color: #d4edda;
# }
# </style>
# <table id="T_1ea73">
#   <caption>Frecuencia Cardíaca Máxima (lpm) por Diagnóstico</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ea73_level0_col0" class="col_heading level0 col0" >N</th>
#       <th id="T_1ea73_level0_col1" class="col_heading level0 col1" >Media</th>
#       <th id="T_1ea73_level0_col2" class="col_heading level0 col2" >Mediana</th>
#       <th id="T_1ea73_level0_col3" class="col_heading level0 col3" >Desv. Std</th>
#       <th id="T_1ea73_level0_col4" class="col_heading level0 col4" >Mínimo</th>
#       <th id="T_1ea73_level0_col5" class="col_heading level0 col5" >Máximo</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Diagnóstico</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ea73_level0_row0" class="row_heading level0 row0" >Con enfermedad</th>
#       <td id="T_1ea73_row0_col0" class="data row0 col0" >139</td>
#       <td id="T_1ea73_row0_col1" class="data row0 col1" >139.300000</td>
#       <td id="T_1ea73_row0_col2" class="data row0 col2" >142.000000</td>
#       <td id="T_1ea73_row0_col3" class="data row0 col3" >22.600000</td>
#       <td id="T_1ea73_row0_col4" class="data row0 col4" >71</td>
#       <td id="T_1ea73_row0_col5" class="data row0 col5" >195</td>
#     </tr>
#     <tr>
#       <th id="T_1ea73_level0_row1" class="row_heading level0 row1" >Sin enfermedad</th>
#       <td id="T_1ea73_row1_col0" class="data row1 col0" >164</td>
#       <td id="T_1ea73_row1_col1" class="data row1 col1" >158.400000</td>
#       <td id="T_1ea73_row1_col2" class="data row1 col2" >161.000000</td>
#       <td id="T_1ea73_row1_col3" class="data row1 col3" >19.200000</td>
#       <td id="T_1ea73_row1_col4" class="data row1 col4" >96</td>
#       <td id="T_1ea73_row1_col5" class="data row1 col5" >202</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">05</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Visualización — Histograma + Densidad
#     </div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   Los pacientes con enfermedad cardíaca alcanzan una frecuencia cardíaca
#   máxima notablemente más baja. La diferencia de medianas es de
#   <strong style="color: #993C1D;">~19 lpm</strong>, un discriminador
#   clínico relevante.
# </div>

# %%
fig, ax = plt.subplots(figsize=(8.4, 8.6))
fig.patch.set_facecolor(COLOR_BG)

for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    sns.histplot(
        data=df[df['target_label'] == tval],
        x=VAR,
        color=color,
        kde=True,
        bins=22,
        alpha=0.45,
        linewidth=0.4,
        line_kws={'linewidth': 2.5},
        ax=ax,
    )

ymax = ax.get_ylim()[1]
for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    med    = df[df['target_label'] == tval][VAR].median()
    offset = +2 if tval == 'Sin enfermedad' else -18
    ax.axvline(med, color=color, linewidth=2, linestyle='--', alpha=0.85)
    ax.text(
        med + offset, ymax * 0.80,
        f'Mediana\n{med:.0f} lpm',
        color=color, fontsize=9, fontweight='bold', va='top',
        bbox=dict(boxstyle='round,pad=0.35', facecolor='white',
                  edgecolor=color, alpha=0.85)
    )

ax.legend(
    handles=[
        mpatches.Patch(facecolor=COLOR_RED, alpha=0.6,
                       label=f'Sin enfermedad  (n={n_sin})'),
        mpatches.Patch(facecolor=COLOR_ACCENT, alpha=0.6,
                       label=f'Con enfermedad  (n={n_con})'),
    ],
    title='Diagnóstico', title_fontsize=11,
    fontsize=11, framealpha=0.9,
    edgecolor='#ccccdd', loc='upper left',
)
ax.set_title(
    'Frecuencia Cardíaca Máxima por Diagnóstico',
    fontsize=15, fontweight='bold', color=COLOR_NAVY, pad=14
)
ax.set_xlabel(LABEL, fontsize=12, color=COLOR_GRAY, labelpad=8)
ax.set_ylabel('Frecuencia', fontsize=12, color=COLOR_GRAY)
ax.yaxis.grid(True)
ax.set_axisbelow(True)
ax.text(
    0.98, 0.97,
    f'Diferencia de medianas: {med_sin - med_con:.0f} lpm\n'
    'Pacientes con enfermedad alcanzan\nuna FC máxima más baja.',
    transform=ax.transAxes, fontsize=9.5, va='top', ha='right',
    bbox=dict(boxstyle='round,pad=0.5', facecolor='white',
              edgecolor=COLOR_ACCENT, alpha=0.92),
    color=COLOR_NAVY
)

fig.text(0.02, 0.005, 'Dataset: Heart Disease UCI · n=303',
         fontsize=8, color=COLOR_GRAY)
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 1])
plt.savefig('thalach_histplot.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('thalach_histplot.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ Gráfico exportado: thalach_histplot.svg / .png")
plt.show()
# Out:
# ✓ Gráfico exportado: thalach_histplot.svg / .png

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">06</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Frecuencia Cardíaca Máxima — Curva de Densidad
#     </div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El kdeplot elimina el ruido visual de las barras y deja visible
#   la separación real entre distribuciones. El área sombreada entre
#   medianas cuantifica la diferencia clínica de forma intuitiva.
# </div>

# %%
VAR   = 'thalach'
LABEL = 'Frecuencia Cardíaca Máxima (lpm)'

n_sin   = df[df['target_label'] == 'Sin enfermedad'].shape[0]
n_con   = df[df['target_label'] == 'Con enfermedad'].shape[0]
med_sin = df[df['target_label'] == 'Sin enfermedad'][VAR].median()
med_con = df[df['target_label'] == 'Con enfermedad'][VAR].median()

fig, ax = plt.subplots(figsize=(8.4, 8.6))
fig.patch.set_facecolor(COLOR_BG)

for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    sns.kdeplot(
        df[df['target_label'] == tval][VAR],
        ax=ax, color=color, linewidth=2.5,
        fill=True, alpha=0.22,
    )

ymax = ax.get_ylim()[1]
for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    med    = df[df['target_label'] == tval][VAR].median()
    offset = +2 if tval == 'Sin enfermedad' else -18
    ax.axvline(med, color=color, linewidth=2, linestyle='--', alpha=0.85)
    ax.text(
        med + offset, ymax * 0.80,
        f'Mediana\n{med:.0f} lpm',
        color=color, fontsize=9, fontweight='bold', va='top',
        bbox=dict(boxstyle='round,pad=0.35', facecolor='white',
                  edgecolor=color, alpha=0.85)
    )

ax.axvspan(med_con, med_sin, alpha=0.06, color=COLOR_NAVY)

ax.legend(
    handles=[
        mpatches.Patch(facecolor=COLOR_RED, alpha=0.5,
                       label=f'Sin enfermedad  (n={n_sin})'),
        mpatches.Patch(facecolor=COLOR_ACCENT, alpha=0.5,
                       label=f'Con enfermedad  (n={n_con})'),
        mpatches.Patch(facecolor=COLOR_NAVY, alpha=0.12,
                       label=f'Diferencia de medianas: {med_sin - med_con:.0f} lpm'),
    ],
    title='Diagnóstico', title_fontsize=11,
    fontsize=11, framealpha=0.9,
    edgecolor='#ccccdd', loc='upper left',
)
ax.set_title(
    'Frecuencia Cardíaca Máxima por Diagnóstico\n(curva de densidad)',
    fontsize=15, fontweight='bold', color=COLOR_NAVY, pad=14
)
ax.set_xlabel(LABEL, fontsize=12, color=COLOR_GRAY, labelpad=8)
ax.set_ylabel('Densidad', fontsize=12, color=COLOR_GRAY)
ax.yaxis.grid(True)
ax.set_axisbelow(True)
ax.text(
    0.98, 0.97,
    f'Diferencia de medianas: {med_sin - med_con:.0f} lpm\n'
    'La FC máxima es un discriminador\nclave entre ambos grupos.',
    transform=ax.transAxes, fontsize=9.5, va='top', ha='right',
    bbox=dict(boxstyle='round,pad=0.5', facecolor='white',
              edgecolor=COLOR_ACCENT, alpha=0.92),
    color=COLOR_NAVY
)
fig.text(0.02, 0.005, 'Dataset: Heart Disease UCI · n=303',
         fontsize=8, color=COLOR_GRAY)
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 1])
plt.savefig('thalach_kdeplot.svg', bbox_inches='tight',
            facecolor=COLOR_BG, format='svg')
plt.savefig('thalach_kdeplot.png', dpi=150,
            bbox_inches='tight', facecolor=COLOR_BG)
print("✓ thalach_kdeplot.svg / .png")
plt.show()
# Out:
# ✓ thalach_kdeplot.svg / .png

# %% [markdown]
# <div style="margin: 40px 0 8px 0;">
#   <div style="height: 1px; background: #e0e0ec; margin-bottom: 24px;"></div>
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #3c78bb; color: white; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">PANEL</div>
#     <div style="font-size: 20px; font-weight: 800; color: #27295a;
#                 font-family: sans-serif;">
#       Variables Cuantitativas — Histograma + Densidad
#     </div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   Las 5 variables cuantitativas del dataset comparadas entre grupos.
#   La frecuencia cardíaca máxima y la depresión ST son las más
#   discriminantes. El colesterol sorprende por su bajo poder de separación.
# </div>

# %%
vars_config = [
    ('age',      'Edad (años)',                      'upper right', +0.5, -6,   '{:.0f} años'),
    ('thalach',  'FC Máxima (lpm)',                  'upper left',  +2,   -18,  '{:.0f} lpm'),
    ('trestbps', 'Presión Arterial (mmHg)',           'upper right', +1,   -12,  '{:.0f} mmHg'),
    ('chol',     'Colesterol (mg/dl)',                'upper right', +2,   -22,  '{:.0f} mg/dl'),
    ('oldpeak',  'Depresión ST (oldpeak)',            'upper right', +0.1, -0.9, '{:.1f}'),
]

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

for ax, (var, label, leg_loc, off_sin, off_con, fmt) in zip(axes_flat, vars_config):

    for tval, color in [
        ('Sin enfermedad', COLOR_RED),
        ('Con enfermedad', COLOR_ACCENT),
    ]:
        sns.histplot(
            data=df[df['target_label'] == tval],
            x=var, color=color, kde=True,
            bins=20, alpha=0.45, linewidth=0.4,
            line_kws={'linewidth': 2.0}, ax=ax,
        )

    ymax = ax.get_ylim()[1]
    for tval, color, offset in [
        ('Sin enfermedad', COLOR_RED,    off_sin),
        ('Con enfermedad', COLOR_ACCENT, off_con),
    ]:
        med = df[df['target_label'] == tval][var].median()
        ax.axvline(med, color=color, linewidth=1.8,
                   linestyle='--', alpha=0.85)
        ax.text(
            med + offset, ymax * 0.78,
            f'Med.\n{fmt.format(med)}',
            color=color, fontsize=8, fontweight='bold', va='top',
            bbox=dict(boxstyle='round,pad=0.25', facecolor='white',
                      edgecolor=color, alpha=0.85)
        )

    med_sin = df[df['target_label'] == 'Sin enfermedad'][var].median()
    med_con = df[df['target_label'] == 'Con enfermedad'][var].median()

    ax.legend(
        handles=[
            mpatches.Patch(facecolor=COLOR_RED, alpha=0.6,
                           label=f'Sin enfermedad (n={n_sin})'),
            mpatches.Patch(facecolor=COLOR_ACCENT, alpha=0.6,
                           label=f'Con enfermedad (n={n_con})'),
        ],
        title='Diagnóstico', title_fontsize=8,
        fontsize=8, framealpha=0.9,
        edgecolor='#ccccdd', loc=leg_loc,
    )
    ax.set_title(label, fontsize=12, fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel('')
    ax.set_ylabel('Frecuencia', fontsize=9, color=COLOR_GRAY)
    ax.yaxis.grid(True)
    ax.set_axisbelow(True)

# Ocultar subplot vacío
axes_flat[5].set_visible(False)

fig.suptitle(
    'Variables Cuantitativas por Diagnóstico Cardíaco Histograma + Curva de Densidad',
    fontsize=16, fontweight='bold', color=COLOR_NAVY, y=1.01
)
fig.text(0.5, 0.98,
         'Dataset: Heart Disease UCI · n=303  |  Línea punteada = mediana por grupo',
         ha='center', fontsize=9, color=COLOR_GRAY)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('panel_histplot.svg', bbox_inches='tight',
            facecolor=COLOR_BG, format='svg')
plt.savefig('panel_histplot.png', dpi=150,
            bbox_inches='tight', facecolor=COLOR_BG)
print("✓ panel_histplot.svg / .png")
plt.show()
# Out:
# ✓ panel_histplot.svg / .png

# %% [markdown]
# <div style="margin: 40px 0 8px 0;">
#   <div style="height: 1px; background: #e0e0ec; margin-bottom: 24px;"></div>
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #3c78bb; color: white; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">PANEL</div>
#     <div style="font-size: 20px; font-weight: 800; color: #27295a;
#                 font-family: sans-serif;">
#       Variables Cuantitativas — Curva de Densidad
#     </div>
#   </div>
#   <div style="height: 2px; background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El kdeplot elimina el ruido visual de las barras. El área sombreada
#   entre medianas cuantifica la separación real entre grupos.
#   Compara con el panel anterior — la forma de las distribuciones
#   queda más clara sin las barras.
# </div>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

for ax, (var, label, leg_loc, off_sin, off_con, fmt) in zip(axes_flat, vars_config):

    for tval, color in [
        ('Sin enfermedad', COLOR_RED),
        ('Con enfermedad', COLOR_ACCENT),
    ]:
        sns.kdeplot(
            df[df['target_label'] == tval][var],
            ax=ax, color=color, linewidth=2.2,
            fill=True, alpha=0.22,
        )

    ymax = ax.get_ylim()[1]
    med_sin = df[df['target_label'] == 'Sin enfermedad'][var].median()
    med_con = df[df['target_label'] == 'Con enfermedad'][var].median()

    for tval, color, offset in [
        ('Sin enfermedad', COLOR_RED,    off_sin),
        ('Con enfermedad', COLOR_ACCENT, off_con),
    ]:
        med = df[df['target_label'] == tval][var].median()
        ax.axvline(med, color=color, linewidth=1.8,
                   linestyle='--', alpha=0.85)
        ax.text(
            med + offset, ymax * 0.78,
            f'Med.\n{fmt.format(med)}',
            color=color, fontsize=8, fontweight='bold', va='top',
            bbox=dict(boxstyle='round,pad=0.25', facecolor='white',
                      edgecolor=color, alpha=0.85)
        )

    ax.axvspan(
        min(med_sin, med_con),
        max(med_sin, med_con),
        alpha=0.06, color=COLOR_NAVY
    )

    ax.legend(
        handles=[
            mpatches.Patch(facecolor=COLOR_RED, alpha=0.5,
                           label=f'Sin enfermedad (n={n_sin})'),
            mpatches.Patch(facecolor=COLOR_ACCENT, alpha=0.5,
                           label=f'Con enfermedad (n={n_con})'),
            mpatches.Patch(facecolor=COLOR_NAVY, alpha=0.12,
                           label=f'Δ med: {abs(med_con - med_sin):.1f}'),
        ],
        title='Diagnóstico', title_fontsize=8,
        fontsize=8, framealpha=0.9,
        edgecolor='#ccccdd', loc=leg_loc,
    )
    ax.set_title(label, fontsize=12, fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel('')
    ax.set_ylabel('Densidad', fontsize=9, color=COLOR_GRAY)
    ax.yaxis.grid(True)
    ax.set_axisbelow(True)

axes_flat[5].set_visible(False)

fig.suptitle(
    'Variables Cuantitativas por Diagnóstico Cardíaco + Curva de Densidad (KDE)',
    fontsize=16, fontweight='bold', color=COLOR_NAVY, y=1.01
)
fig.text(0.5, 0.98,
         'Dataset: Heart Disease UCI · n=303  |  '
         'Área sombreada = diferencia entre medianas',
         ha='center', fontsize=9, color=COLOR_GRAY)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('panel_kdeplot.svg', bbox_inches='tight',
            facecolor=COLOR_BG, format='svg')
plt.savefig('panel_kdeplot.png', dpi=150,
            bbox_inches='tight', facecolor=COLOR_BG)
print("✓ panel_kdeplot.svg / .png")
plt.show()
# Out:
# ✓ panel_kdeplot.svg / .png

# %% [markdown]
# <div style="margin: 40px 0 8px 0;">
#   <div style="height: 1px; background: #e0e0ec; margin-bottom: 24px;"></div>
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: linear-gradient(135deg, #27295a, #3c78bb);
#                 color: white; font-size: 11px; font-weight: 700;
#                 letter-spacing: 2px; padding: 6px 14px;
#                 border-radius: 4px; font-family: sans-serif;">
#       NIVEL INTERMEDIO
#     </div>
#     <div style="font-size: 20px; font-weight: 800; color: #27295a;
#                 font-family: sans-serif;">
#       Variables Cuantitativas — Distribución y Comparación por Grupos
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;">
#   <strong style="color: #27295a;">Objetivo:</strong>
#   Comparar la distribución de cada variable cuantitativa entre pacientes
#   con y sin enfermedad cardíaca usando gráficos que van más allá del
#   histograma y la curva de densidad.
# </div>

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">07</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Boxplot agrupado por diagnóstico
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El boxplot agrupado muestra mediana, rango intercuartílico y outliers
#   univariados por grupo diagnóstico. Es el complemento natural del análisis
#   de Mahalanobis — lo que el boxplot detecta por variable vs lo que MCD
#   detecta en la combinación.
# </div>

# %%
vars_config = [
    ('age',      'Edad (años)',               'upper right'),
    ('thalach',  'FC Máxima (lpm)',            'upper left'),
    ('trestbps', 'Presión Arterial (mmHg)',    'upper right'),
    ('chol',     'Colesterol (mg/dl)',          'upper right'),
    ('oldpeak',  'Depresión ST',               'upper right'),
]

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

for ax, (var, label, leg_loc) in zip(axes_flat, vars_config):

    sns.boxplot(
        data=df,
        x='target_label',
        y=var,
        hue='target_label',
        palette={'Sin enfermedad': COLOR_RED,
                 'Con enfermedad': COLOR_ACCENT},
        width=0.5,
        linewidth=1.2,
        flierprops=dict(marker='o', markerfacecolor=COLOR_GRAY,
                        markersize=4, alpha=0.5,
                        markeredgecolor='white', markeredgewidth=0.3),
        ax=ax,
        legend=False,
    )

    # Medianas anotadas
    for i, tval in enumerate(['Sin enfermedad', 'Con enfermedad']):
        med = df[df['target_label'] == tval][var].median()
        ax.text(i, med, f' {med:.1f}',
                ha='left', va='center',
                fontsize=8.5, fontweight='bold',
                color=COLOR_NAVY)

    ax.set_title(label, fontsize=12, fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel('')
    ax.set_ylabel(label, fontsize=9, color=COLOR_GRAY)
    ax.yaxis.grid(True, alpha=0.4)
    ax.set_axisbelow(True)
    ax.tick_params(axis='x', labelsize=9)

axes_flat[5].set_visible(False)

fig.suptitle(
    'Boxplot por Diagnóstico Cardíaco\nComparación de Variables Cuantitativas',
    fontsize=16, fontweight='bold', color=COLOR_NAVY, y=1.01
)
fig.text(0.5, 0.98,
         'Dataset: Heart Disease UCI · n=303  |  '
         'Puntos = outliers univariados',
         ha='center', fontsize=9, color=COLOR_GRAY)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('g07_boxplot_agrupado.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g07_boxplot_agrupado.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ G07 guardado")
plt.show()
# Out:
# ✓ G07 guardado

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">08</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Boxenplot por diagnóstico
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El boxenplot o letter-value plot muestra más cuantiles que el boxplot
#   estándar. Con n=303 tiene suficientes datos para ser informativo.
#   Las cajas más externas representan las colas de la distribución
#   con mayor detalle que el bigote clásico.
# </div>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

for ax, (var, label, leg_loc) in zip(axes_flat, vars_config):

    sns.boxenplot(
        data=df,
        x='target_label',
        y=var,
        hue='target_label',
        palette={'Sin enfermedad': COLOR_RED,
                 'Con enfermedad': COLOR_ACCENT},
        width=0.55,
        linewidth=0.8,
        ax=ax,
        legend=False,
    )

    # Medianas anotadas
    for i, tval in enumerate(['Sin enfermedad', 'Con enfermedad']):
        med = df[df['target_label'] == tval][var].median()
        ax.text(i, med, f' {med:.1f}',
                ha='left', va='center',
                fontsize=8.5, fontweight='bold',
                color=COLOR_NAVY)

    ax.set_title(label, fontsize=12, fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel('')
    ax.set_ylabel(label, fontsize=9, color=COLOR_GRAY)
    ax.yaxis.grid(True, alpha=0.4)
    ax.set_axisbelow(True)
    ax.tick_params(axis='x', labelsize=9)

axes_flat[5].set_visible(False)

fig.suptitle(
    'Boxenplot por Diagnóstico Cardíaco\n'
    'Letter-Value Plot — más cuantiles que el boxplot estándar',
    fontsize=16, fontweight='bold', color=COLOR_NAVY, y=1.01
)
fig.text(0.5, 0.98,
         'Dataset: Heart Disease UCI · n=303  |  '
         'Cajas externas = colas de la distribución',
         ha='center', fontsize=9, color=COLOR_GRAY)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('g08_boxenplot.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g08_boxenplot.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ G08 guardado")
plt.show()
# Out:
# ✓ G08 guardado

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">09</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Violinplot con split por diagnóstico
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El violinplot dividido muestra la forma completa de cada distribución
#   en una sola figura. La mitad izquierda representa un grupo y la derecha
#   el otro. Donde el violín es más ancho hay mayor concentración de datos.
#   Más informativo que el boxplot porque no oculta la forma de la distribución
#   detrás de cinco números resumen.
# </div>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

for ax, (var, label, leg_loc) in zip(axes_flat, vars_config):

    sns.violinplot(
        data=df,
        x='target_label',
        y=var,
        hue='target_label',
        palette={'Sin enfermedad': COLOR_RED,
                 'Con enfermedad': COLOR_ACCENT},
        split=False,
        inner='box',       # muestra boxplot mini dentro del violín
        linewidth=1.0,
        alpha=0.75,
        ax=ax,
        legend=False,
    )

    # Medianas anotadas
    for i, tval in enumerate(['Sin enfermedad', 'Con enfermedad']):
        med = df[df['target_label'] == tval][var].median()
        ax.text(i, med, f' {med:.1f}',
                ha='left', va='center',
                fontsize=8.5, fontweight='bold',
                color=COLOR_NAVY)

    ax.set_title(label, fontsize=12, fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel('')
    ax.set_ylabel(label, fontsize=9, color=COLOR_GRAY)
    ax.yaxis.grid(True, alpha=0.4)
    ax.set_axisbelow(True)
    ax.tick_params(axis='x', labelsize=9)

axes_flat[5].set_visible(False)

fig.suptitle(
    'Violinplot por Diagnóstico Cardíaco\n'
    'Forma completa de la distribución por grupo',
    fontsize=16, fontweight='bold', color=COLOR_NAVY, y=1.01
)
fig.text(0.5, 0.98,
         'Dataset: Heart Disease UCI · n=303  |  '
         'Ancho del violín = densidad de datos  |  '
         'Caja interior = IQR y mediana',
         ha='center', fontsize=9, color=COLOR_GRAY)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('g09_violinplot.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g09_violinplot.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ G09 guardado")
plt.show()
# Out:
# ✓ G09 guardado

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">10</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Stripplot con boxplot superpuesto
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El stripplot muestra cada observación individual encima del boxplot.
#   Es el gráfico más honesto estadísticamente porque no oculta ningún dato.
#   Con n=303 el gráfico no se satura. Los puntos revelan si la distribución
#   es continua, discreta o tiene agrupaciones que el boxplot no captura.
# </div>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

for ax, (var, label, leg_loc) in zip(axes_flat, vars_config):

    # Boxplot base
    bp = sns.boxplot(
        data=df,
        x='target_label',
        y=var,
        hue='target_label',
        palette={'Sin enfermedad': COLOR_RED,
                 'Con enfermedad': COLOR_ACCENT},
        width=0.45,
        linewidth=1.0,
        fliersize=0,
        ax=ax,
        legend=False,
    )

    # Aplicar alpha manualmente sobre los patches del boxplot
    for patch in ax.patches:
        r, g, b, a = patch.get_facecolor()
        patch.set_facecolor((r, g, b, 0.35))

    # Stripplot encima
    sns.stripplot(
        data=df,
        x='target_label',
        y=var,
        hue='target_label',
        palette={'Sin enfermedad': COLOR_RED,
                 'Con enfermedad': COLOR_ACCENT},
        size=3.2,
        alpha=0.45,
        jitter=True,
        dodge=False,
        ax=ax,
        legend=False,
    )

    # Medianas anotadas
    for i, tval in enumerate(['Sin enfermedad', 'Con enfermedad']):
        med = df[df['target_label'] == tval][var].median()
        ax.text(i, med, f' {med:.1f}',
                ha='left', va='center',
                fontsize=8.5, fontweight='bold',
                color=COLOR_NAVY)

    ax.set_title(label, fontsize=12, fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel('')
    ax.set_ylabel(label, fontsize=9, color=COLOR_GRAY)
    ax.yaxis.grid(True, alpha=0.4)
    ax.set_axisbelow(True)
    ax.tick_params(axis='x', labelsize=9)

axes_flat[5].set_visible(False)

fig.suptitle(
    'Stripplot con Boxplot por Diagnóstico Cardíaco\n'
    'Cada punto representa una observación individual',
    fontsize=16, fontweight='bold', color=COLOR_NAVY, y=1.01
)
fig.text(0.5, 0.98,
         'Dataset: Heart Disease UCI · n=303  |  '
         'Puntos = observaciones individuales  |  '
         'Caja = resumen estadístico',
         ha='center', fontsize=9, color=COLOR_GRAY)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('g10_strip_boxplot.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g10_strip_boxplot.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ G10 guardado")
plt.show()
# Out:
# ✓ G10 guardado

# %% [markdown]
# <div style="margin: 24px 0 8px 0;">
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">11</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       Jointplot — FC Máxima vs Depresión ST
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   Las dos variables más discriminantes del dataset en un gráfico bivariado.
#   El scatter central muestra la relación entre ambas, los marginales
#   muestran su distribución individual. La separación entre grupos es
#   visible en los dos ejes simultáneamente.
# </div>

# %%
# Jointplot no admite múltiples axes — gráfico independiente
g = sns.JointGrid(
    data=df,
    x='thalach',
    y='oldpeak',
    height=9,
    ratio=4,
)
g.figure.patch.set_facecolor(COLOR_BG)

# Scatter central por grupo
for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    subset = df[df['target_label'] == tval]
    g.ax_joint.scatter(
        subset['thalach'], subset['oldpeak'],
        c=color, alpha=0.45, s=30,
        edgecolors='white', linewidth=0.3,
        label=tval, zorder=3
    )

# KDE marginal x
for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    subset = df[df['target_label'] == tval]
    sns.kdeplot(
        subset['thalach'],
        ax=g.ax_marg_x,
        color=color, fill=True,
        alpha=0.25, linewidth=1.5
    )

# KDE marginal y
for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    subset = df[df['target_label'] == tval]
    sns.kdeplot(
        subset['oldpeak'],
        ax=g.ax_marg_y,
        color=color, fill=True,
        alpha=0.25, linewidth=1.5,
        vertical=True
    )

# Líneas de mediana
for tval, color in [
    ('Sin enfermedad', COLOR_RED),
    ('Con enfermedad', COLOR_ACCENT),
]:
    subset = df[df['target_label'] == tval]
    g.ax_joint.axvline(
        subset['thalach'].median(),
        color=color, linewidth=1.2,
        linestyle='--', alpha=0.6
    )
    g.ax_joint.axhline(
        subset['oldpeak'].median(),
        color=color, linewidth=1.2,
        linestyle='--', alpha=0.6
    )

g.ax_joint.set_xlabel(
    'FC Máxima (lpm)', fontsize=11, color=COLOR_GRAY, labelpad=8
)
g.ax_joint.set_ylabel(
    'Depresión ST (oldpeak)', fontsize=11, color=COLOR_GRAY
)
g.ax_joint.legend(
    title='Diagnóstico', fontsize=9,
    title_fontsize=9, framealpha=0.9,
    edgecolor='#ccccdd'
)
g.ax_joint.grid(True, alpha=0.35)
g.ax_joint.set_axisbelow(True)
g.ax_joint.set_facecolor(COLOR_BG)
g.ax_marg_x.set_facecolor(COLOR_BG)
g.ax_marg_y.set_facecolor(COLOR_BG)

g.figure.suptitle(
    'FC Máxima vs Depresión ST - Jointplot con distribuciones marginales',
    fontsize=14, fontweight='bold', color=COLOR_NAVY, y=1.01
)
g.figure.text(0.5, 0.96,
              'Dataset: Heart Disease UCI · n=303  |  '
              'Línea punteada = mediana por grupo',
              ha='center', fontsize=9, color=COLOR_GRAY)
g.figure.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
              fontsize=8, color=COLOR_NAVY,
              alpha=0.5, fontweight='bold')
g.figure.text(0.98, 0.005, '#PensarConDatos',
              fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('g11_jointplot.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g11_jointplot.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ G11 guardado")
plt.show()
# Out:
# ✓ G11 guardado

# %% [markdown]
# <div style="margin: 40px 0 8px 0;">
#   <div style="height: 1px; background: #e0e0ec; margin-bottom: 24px;"></div>
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">12</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       4 formas de visualizar la misma distribución
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Variable:</strong>
#   Presión Arterial en Reposo (mmHg) &nbsp;·&nbsp;
#   <strong style="color: #27295a;">n:</strong> 303 pacientes
#   &nbsp;·&nbsp;
#   <strong style="color: #27295a;">Objetivo:</strong>
#   Comparar qué información revela cada tipo de gráfico sobre
#   la misma distribución y en qué escenario conviene usar cada uno.
# </div>
#
# <div style="display: flex; gap: 10px; flex-wrap: wrap; margin-bottom: 12px;">
#   <span style="background: rgba(60,120,187,0.15); color: #27295a;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #3c78bb;">
#     Boxplot clásico
#   </span>
#   <span style="background: rgba(15,110,86,0.12); color: #085041;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #0F6E56;">
#     Boxenplot
#   </span>
#   <span style="background: rgba(239,159,39,0.15); color: #633806;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #EF9F27;">
#     Violinplot
#   </span>
#   <span style="background: rgba(39,41,90,0.10); color: #27295a;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #27295a;">
#     Strip + Boxplot
#   </span>
# </div>

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Comparativa de 4 tipos de boxplot — FC Máxima (thalach)
# ══════════════════════════════════════════════════════════════════════════════

COLOR_NAVY   = '#27295a'
COLOR_BLUE   = '#304b9a'
COLOR_ACCENT = '#3c78bb'
COLOR_LIGHT  = '#85B7EB'
COLOR_GRAY   = '#71706f'
COLOR_GREEN  = '#0F6E56'
COLOR_RED    = '#993C1D'
COLOR_AMBER  = '#EF9F27'

# ── Paletas por panel ──────────────────────────────────────────────────────────
paletas = [
    {'Sin enfermedad': COLOR_RED,    'Con enfermedad': COLOR_ACCENT},  # Panel 1
    {'Sin enfermedad': COLOR_GREEN,  'Con enfermedad': COLOR_BLUE},    # Panel 2
    {'Sin enfermedad': COLOR_AMBER,  'Con enfermedad': COLOR_NAVY},    # Panel 3
    {'Sin enfermedad': COLOR_LIGHT,  'Con enfermedad': COLOR_RED},     # Panel 4
]

VAR   = 'thalach'
LABEL = 'Frecuencia Cardíaca Máxima (lpm)'

fig, axes = plt.subplots(1, 4, figsize=(22, 9))
fig.patch.set_facecolor(COLOR_BG)



titulos = [
    'Boxplot clásico',
    'Boxenplot',
    'Violinplot',
    'Strip + Boxplot',
]

insights = [
    'Mediana, IQR y bigotes.\nOutliers como puntos.\nResumen en 5 números.',
    'Más cuantiles que\nel boxplot estándar.\nMejor en colas.',
    'Forma completa de\nla distribución.\nMás informativo.',
    'Cada observación\nvisible. El más\nhonesto con los datos.',
]

cuando_usar = [
    'Cuando necesitas\nun resumen rápido\ny universal.',
    'Cuando las colas\ny asimetría importan\ny n > 200.',
    'Cuando la forma\nde la distribución\nes el mensaje.',
    'Cuando quieres\nmostrar todos\nlos datos reales.',
]

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 1 — Boxplot clásico
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[0]
sns.boxplot(
    data=df, x='target_label', y=VAR,
    hue='target_label',
    palette=paletas[0],
    width=0.5, linewidth=1.2,
    flierprops=dict(marker='o', markersize=4, alpha=0.5,
                    markeredgecolor='white', markeredgewidth=0.3),
    ax=ax, legend=False,
)
for patch in ax.patches:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, 0.75))

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 2 — Boxenplot
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[1]
sns.boxenplot(
    data=df, x='target_label', y=VAR,
    hue='target_label',
    palette=paletas[1],
    width=0.55, linewidth=0.8,
    ax=ax, legend=False,
)

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 3 — Violinplot
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[2]
sns.violinplot(
    data=df, x='target_label', y=VAR,
    hue='target_label',
    palette=paletas[2],
    width=0.7, linewidth=1.0,
    inner='box',
    alpha=0.8,
    ax=ax, legend=False,
)

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 4 — Stripplot + Boxplot
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[3]
bp = sns.boxplot(
    data=df, x='target_label', y=VAR,
    hue='target_label',
    palette=paletas[3],
    width=0.45, linewidth=1.0,
    fliersize=0,
    ax=ax, legend=False,
)
for patch in ax.patches:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, 0.30))

sns.stripplot(
    data=df, x='target_label', y=VAR,
    hue='target_label',
    palette=paletas[3],
    size=3.2, alpha=0.50,
    jitter=True, dodge=False,
    ax=ax, legend=False,
)

# ══════════════════════════════════════════════════════════════════════════════
# Formato común para los 4 paneles
# ══════════════════════════════════════════════════════════════════════════════
for i, ax in enumerate(axes):
    pal = paletas[i]

    # Medianas anotadas
    for j, tval in enumerate(['Sin enfermedad', 'Con enfermedad']):
        med = df[df['target_label'] == tval][VAR].median()
        ax.text(
            j, med, f' {med:.0f}',
            ha='left', va='center',
            fontsize=8.5, fontweight='bold',
            color=COLOR_NAVY, zorder=10
        )

    # Leyenda manual con patches
    patch_sin = mpatches.Patch(
        facecolor=pal['Sin enfermedad'], alpha=0.8,
        label=f'Sin enf. (n={n_sin})'
    )
    patch_con = mpatches.Patch(
        facecolor=pal['Con enfermedad'], alpha=0.8,
        label=f'Con enf. (n={n_con})'
    )
    ax.legend(
        handles=[patch_sin, patch_con],
        fontsize=8, framealpha=0.9,
        edgecolor='#ccccdd', loc='lower right'
    )

    # Título del panel
    ax.set_title(
        titulos[i],
        fontsize=13, fontweight='bold',
        color=COLOR_NAVY, pad=10
    )
    ax.set_xlabel('', fontsize=9)
    ax.set_ylabel(LABEL if i == 0 else '', fontsize=10, color=COLOR_GRAY)
    ax.yaxis.grid(True, alpha=0.4)
    ax.set_axisbelow(True)
    ax.tick_params(axis='x', labelsize=9)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_facecolor(COLOR_BG)

    # Insight box inferior
    ax.text(
        0.5, -0.18,
        insights[i],
        transform=ax.transAxes,
        fontsize=8, ha='center', va='top',
        color=COLOR_NAVY,
        bbox=dict(boxstyle='round,pad=0.4', facecolor='white',
                  edgecolor='#ccccdd', alpha=0.9)
    )

    # Cuándo usar — debajo del insight
    ax.text(
        0.5, -0.35,
        cuando_usar[i],
        transform=ax.transAxes,
        fontsize=7.5, ha='center', va='top',
        color=COLOR_GRAY,
        style='italic'
    )

# ── Título general ─────────────────────────────────────────────────────────────
fig.suptitle(
    '4 formas de visualizar la misma distribución\n'
    'Frecuencia Cardíaca Máxima por Diagnóstico Cardíaco',
    fontsize=16, fontweight='bold',
    color=COLOR_NAVY, y=1.01
)
fig.text(
    0.5, 0.985,
    'Dataset: Heart Disease UCI · n=303  |  '
    'Misma variable, distintos niveles de detalle',
    ha='center', fontsize=9, color=COLOR_GRAY
)

# ── Footer ─────────────────────────────────────────────────────────────────────
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY, alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')
fig.text(0.5, 0.005, 'Dataset: Heart Disease UCI · n=303',
         fontsize=8, color=COLOR_GRAY, ha='center')

plt.tight_layout(rect=[0, 0.12, 1, 0.98])
plt.savefig('g_comparativa_boxplots.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g_comparativa_boxplots.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ Comparativa 4 boxplots guardada")
plt.show()
# Out:
# ✓ Comparativa 4 boxplots guardada

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Comparativa de 4 tipos de boxplot — Presión Arterial (trestbps)
# Sin separación por target — distribución general
# ══════════════════════════════════════════════════════════════════════════════

VAR   = 'trestbps'
LABEL = 'Presión Arterial en Reposo (mmHg)'

fig, axes = plt.subplots(1, 4, figsize=(14, 10))
fig.patch.set_facecolor(COLOR_BG)

colores = [COLOR_ACCENT, COLOR_GREEN, COLOR_AMBER, COLOR_NAVY]

titulos = [
    'Boxplot clásico',
    'Boxenplot',
    'Violinplot',
    'Strip + Boxplot',
]

insights = [
    'Mediana, IQR y bigotes.\nOutliers como puntos.\nResumen en 5 números.',
    'Más cuantiles que\nel boxplot estándar.\nMejor en colas.',
    'Forma completa de\nla distribución.\nMás informativo.',
    'Cada observación\nvisible. El más\nhonesto con los datos.',
]

cuando_usar = [
    'Cuando necesitas\nun resumen rápido\ny universal.',
    'Cuando las colas\ny asimetría importan\ny n > 200.',
    'Cuando la forma\nde la distribución\nes el mensaje.',
    'Cuando quieres\nmostrar todos\nlos datos reales.',
]

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 1 — Boxplot clásico
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[0]
sns.boxplot(
    data=df, y=VAR,
    color=colores[0],
    width=0.4, linewidth=1.5,
    flierprops=dict(marker='o', markersize=5,
                    markerfacecolor=colores[0],
                    markeredgecolor='white',
                    markeredgewidth=0.4,
                    alpha=0.6),
    ax=ax,
)
for patch in ax.patches:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, 0.65))

# Anotaciones de los 5 números resumen
q1  = df[VAR].quantile(0.25)
med = df[VAR].median()
q3  = df[VAR].quantile(0.75)
iqr = q3 - q1
low = df[VAR][df[VAR] >= q1 - 1.5*iqr].min()
high= df[VAR][df[VAR] <= q3 + 1.5*iqr].max()

for val, nombre in [
    (low,  f'Mín. bigote\n{low:.0f}'),
    (q1,   f'Q1\n{q1:.0f}'),
    (med,  f'Mediana\n{med:.0f}'),
    (q3,   f'Q3\n{q3:.0f}'),
    (high, f'Máx. bigote\n{high:.0f}'),
]:
    ax.annotate(
        nombre,
        xy=(0, val),
        xytext=(0.32, val),
        fontsize=7.5, color=COLOR_NAVY,
        fontweight='bold', va='center',
        arrowprops=dict(arrowstyle='-',
                        color='#ccccdd',
                        lw=0.8)
    )

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 2 — Boxenplot
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[1]
sns.boxenplot(
    data=df, y=VAR,
    color=colores[1],
    width=0.45, linewidth=0.8,
    ax=ax,
)

# Anotación de cuantiles adicionales
for q, label in [
    (0.125, 'P12.5'),
    (0.25,  'P25'),
    (0.50,  'P50'),
    (0.75,  'P75'),
    (0.875, 'P87.5'),
]:
    val = df[VAR].quantile(q)
    ax.annotate(
        f'{label}\n{val:.0f}',
        xy=(0, val),
        xytext=(0.32, val),
        fontsize=7.5, color=COLOR_NAVY,
        fontweight='bold', va='center',
        arrowprops=dict(arrowstyle='-',
                        color='#ccccdd',
                        lw=0.8)
    )

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 3 — Violinplot
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[2]
parts = ax.violinplot(
    df[VAR].dropna(),
    positions=[0],
    showmedians=True,
    showextrema=True,
    widths=0.6,
)
parts['bodies'][0].set_facecolor(colores[2])
parts['bodies'][0].set_alpha(0.65)
parts['bodies'][0].set_edgecolor('white')
parts['cmedians'].set_color(COLOR_NAVY)
parts['cmedians'].set_linewidth(2)
parts['cbars'].set_color(COLOR_GRAY)
parts['cmaxes'].set_color(COLOR_GRAY)
parts['cmins'].set_color(COLOR_GRAY)

# Anotación mediana y moda aproximada
ax.annotate(
    f'Mediana\n{med:.0f}',
    xy=(0, med),
    xytext=(0.32, med),
    fontsize=7.5, color=COLOR_NAVY,
    fontweight='bold', va='center',
    arrowprops=dict(arrowstyle='-',
                    color='#ccccdd', lw=0.8)
)
# Pico de densidad (moda aproximada con KDE)
from scipy.stats import gaussian_kde
kde_vals = gaussian_kde(df[VAR].dropna())
x_range  = np.linspace(df[VAR].min(), df[VAR].max(), 500)
moda_approx = x_range[np.argmax(kde_vals(x_range))]
ax.annotate(
    f'Pico densidad\n{moda_approx:.0f}',
    xy=(0, moda_approx),
    xytext=(0.32, moda_approx),
    fontsize=7.5, color=COLOR_AMBER,
    fontweight='bold', va='center',
    arrowprops=dict(arrowstyle='-',
                    color='#ccccdd', lw=0.8)
)
ax.set_xlim(-0.6, 0.8)

# ══════════════════════════════════════════════════════════════════════════════
# PANEL 4 — Stripplot + Boxplot
# ══════════════════════════════════════════════════════════════════════════════
ax = axes[3]
bp = sns.boxplot(
    data=df, y=VAR,
    color=colores[3],
    width=0.35, linewidth=1.0,
    fliersize=0,
    ax=ax,
)
for patch in ax.patches:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, 0.25))

sns.stripplot(
    data=df, y=VAR,
    color=colores[3],
    size=3.0, alpha=0.40,
    jitter=True,
    ax=ax,
)

# Anotación n total
ax.text(
    0.5, 0.98,
    f'n = {len(df[VAR].dropna())} observaciones',
    transform=ax.transAxes,
    fontsize=8, ha='center', va='top',
    color=COLOR_NAVY,
    bbox=dict(boxstyle='round,pad=0.3',
              facecolor='white',
              edgecolor='#ccccdd',
              alpha=0.9)
)

# ══════════════════════════════════════════════════════════════════════════════
# Formato común
# ══════════════════════════════════════════════════════════════════════════════
for i, ax in enumerate(axes):
    ax.set_title(
        titulos[i],
        fontsize=13, fontweight='bold',
        color=COLOR_NAVY, pad=10
    )
    ax.set_xlabel('')
    ax.set_ylabel(LABEL if i == 0 else '',
                  fontsize=10, color=COLOR_GRAY)
    ax.yaxis.grid(True, alpha=0.4)
    ax.set_axisbelow(True)
    ax.tick_params(axis='x', labelbottom=False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_facecolor(COLOR_BG)

    # Barra de color superior por panel
    ax.axhline(
        df[VAR].max() * 1.02,
        color=colores[i],
        linewidth=3, alpha=0.4,
        clip_on=False
    )

    # Insight box
    ax.text(
        0.5, -0.10,
        insights[i],
        transform=ax.transAxes,
        fontsize=8, ha='center', va='top',
        color=COLOR_NAVY,
        bbox=dict(boxstyle='round,pad=0.4',
                  facecolor='white',
                  edgecolor=colores[i],
                  alpha=0.9,
                  linewidth=1.2)
    )

    # Cuándo usar
    ax.text(
        0.5, -0.26,
        cuando_usar[i],
        transform=ax.transAxes,
        fontsize=7.5, ha='center', va='top',
        color=COLOR_GRAY,
        style='italic'
    )

# ── Título general ─────────────────────────────────────────────────────────────
fig.suptitle(
    '4 formas de visualizar la misma distribución',
    fontsize=16, fontweight='bold',
    color=COLOR_NAVY, y=1.02
)
fig.text(
    0.5, 0.985,
    'Dataset: Heart Disease UCI · n=303  |  '
    'Misma variable, distintos niveles de detalle',
    ha='center', fontsize=9, color=COLOR_GRAY
)

# ── Footer ─────────────────────────────────────────────────────────────────────
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY,
         alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')
fig.text(0.5, 0.005,
         'Dataset: Heart Disease UCI · n=303',
         fontsize=8, color=COLOR_GRAY, ha='center')

plt.tight_layout(rect=[0, 0.14, 1, 0.98])
plt.savefig('g_comparativa_boxplots_trestbps.svg',
            bbox_inches='tight', facecolor=COLOR_BG, format='svg')
plt.savefig('g_comparativa_boxplots_trestbps.png',
            dpi=150, bbox_inches='tight', facecolor=COLOR_BG)
print("✓ Comparativa 4 boxplots presión arterial guardada")
plt.show()
# Out:
# ✓ Comparativa 4 boxplots presión arterial guardada

# %% [markdown]
# <div style="margin: 40px 0 8px 0;">
#   <div style="height: 1px; background: #e0e0ec; margin-bottom: 24px;"></div>
#   <div style="display: flex; align-items: center; gap: 12px;">
#     <div style="background: #27295a; color: #85B7EB; font-size: 11px;
#                 font-weight: 700; letter-spacing: 2px; padding: 4px 10px;
#                 border-radius: 4px; font-family: sans-serif;">13</div>
#     <div style="font-size: 18px; font-weight: 700; color: #27295a;
#                 font-family: sans-serif;">
#       ECDF — Función de Distribución Acumulada Empírica
#     </div>
#   </div>
#   <div style="height: 2px;
#               background: linear-gradient(90deg, #3c78bb, transparent);
#               margin-top: 8px; border-radius: 2px;"></div>
# </div>
#
# <div style="background: #f0f0f8; border-left: 4px solid #3c78bb;
#             padding: 10px 16px; border-radius: 0 6px 6px 0;
#             font-family: sans-serif; font-size: 12px; color: #71706f;
#             margin-bottom: 8px;">
#   <strong style="color: #27295a;">Insight:</strong>
#   El ECDF muestra exactamente qué proporción de observaciones
#   tiene un valor menor o igual a x, sin ninguna decisión arbitraria
#   sobre bins o suavizado. Es el gráfico más honesto para comparar
#   distribuciones entre grupos.
# </div>
#
# <div style="display: flex; gap: 10px; flex-wrap: wrap; margin-bottom: 12px;">
#   <span style="background: rgba(60,120,187,0.15); color: #27295a;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #3c78bb;">
#     Sin bins
#   </span>
#   <span style="background: rgba(15,110,86,0.12); color: #085041;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #0F6E56;">
#     Percentiles directos
#   </span>
#   <span style="background: rgba(239,159,39,0.15); color: #633806;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #EF9F27;">
#     Comparación por grupos
#   </span>
#   <span style="background: rgba(153,60,29,0.10); color: #993C1D;
#                padding: 4px 12px; border-radius: 20px; font-size: 11px;
#                font-family: sans-serif; font-weight: 600;
#                border: 1px solid #993C1D;">
#     5 variables
#   </span>
# </div>

# %%
# ══════════════════════════════════════════════════════════════════════════════
# G12 — ECDF Plot — todas las variables cuantitativas
# ══════════════════════════════════════════════════════════════════════════════

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.patch.set_facecolor(COLOR_BG)
axes_flat = axes.flat

vars_config = [
    ('age',      'Edad (años)'),
    ('thalach',  'FC Máxima (lpm)'),
    ('trestbps', 'Presión Arterial (mmHg)'),
    ('chol',     'Colesterol (mg/dl)'),
    ('oldpeak',  'Depresión ST'),
]

for ax, (var, label) in zip(axes_flat, vars_config):

    # ECDF por grupo
    for tval, color in [
        ('Sin enfermedad', COLOR_RED),
        ('Con enfermedad', COLOR_ACCENT),
    ]:
        subset = df[df['target_label'] == tval][var].dropna()
        n      = len(subset)

        # Calcular ECDF manualmente
        x = np.sort(subset)
        y = np.arange(1, n + 1) / n

        ax.plot(x, y,
                color=color, linewidth=2.2,
                alpha=0.88,
                label=f'{tval}  (n={n})')

        # Área bajo la curva sombreada
        ax.fill_between(x, 0, y,
                        color=color, alpha=0.06)

    # Líneas de referencia en percentiles clave
    for pct, label_pct in [(0.25, 'P25'), (0.50, 'P50'), (0.75, 'P75')]:
        ax.axhline(pct, color=COLOR_GRAY, linewidth=0.8,
                   linestyle=':', alpha=0.5)
        ax.text(ax.get_xlim()[0] if ax.get_xlim()[0] != 0
                else df[var].min(),
                pct + 0.015,
                label_pct,
                fontsize=7, color=COLOR_GRAY, alpha=0.7)

    # Línea en P50 más marcada
    ax.axhline(0.50, color=COLOR_GRAY, linewidth=1.0,
               linestyle='--', alpha=0.4)

    # Medianas anotadas con líneas verticales
    for tval, color in [
        ('Sin enfermedad', COLOR_RED),
        ('Con enfermedad', COLOR_ACCENT),
    ]:
        med = df[df['target_label'] == tval][var].median()
        ax.axvline(med, color=color, linewidth=1.2,
                   linestyle='--', alpha=0.55)
        ax.scatter(med, 0.5, c=color, s=60,
                   edgecolors='white', lw=0.8,
                   zorder=5, alpha=0.9)

    ax.set_title(label, fontsize=12,
                 fontweight='bold',
                 color=COLOR_NAVY, pad=8)
    ax.set_xlabel(label, fontsize=9, color=COLOR_GRAY)
    ax.set_ylabel('Proporción acumulada',
                  fontsize=9, color=COLOR_GRAY)
    ax.set_ylim(0, 1.05)
    ax.legend(fontsize=8, framealpha=0.88,
              edgecolor='#ccccdd', loc='upper left')
    ax.yaxis.grid(True, alpha=0.35, color='#e0e0ec')
    ax.xaxis.grid(True, alpha=0.35, color='#e0e0ec')
    ax.set_axisbelow(True)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

axes_flat[5].set_visible(False)

# ── Insight box en el subplot vacío ───────────────────────────────────────────
ax_insight = fig.add_axes([0.68, 0.08, 0.28, 0.38])
ax_insight.set_facecolor('#f0f0f8')
ax_insight.set_xticks([])
ax_insight.set_yticks([])
for spine in ax_insight.spines.values():
    spine.set_edgecolor('#3c78bb')
    spine.set_linewidth(0.8)

ax_insight.text(
    0.5, 0.95,
    'Cómo leer el ECDF',
    ha='center', va='top',
    fontsize=11, fontweight='bold',
    color=COLOR_NAVY,
    transform=ax_insight.transAxes
)
ax_insight.text(
    0.5, 0.80,
    'El eje Y indica qué proporción\n'
    'de pacientes tiene un valor\n'
    'menor o igual al del eje X.',
    ha='center', va='top',
    fontsize=9, color=COLOR_NAVY,
    transform=ax_insight.transAxes
)
ax_insight.text(
    0.5, 0.55,
    '● Punto en P50 (y=0.5)\n'
    '  = mediana del grupo',
    ha='center', va='top',
    fontsize=9, color=COLOR_GRAY,
    transform=ax_insight.transAxes
)
ax_insight.text(
    0.5, 0.38,
    'Curva más a la derecha\n'
    '→ distribución con\n'
    '   valores más altos',
    ha='center', va='top',
    fontsize=9, color=COLOR_GRAY,
    transform=ax_insight.transAxes
)
ax_insight.text(
    0.5, 0.18,
    'No depende de bins.\n'
    'Más honesto que el histograma.',
    ha='center', va='top',
    fontsize=9, color=COLOR_ACCENT,
    fontweight='bold',
    transform=ax_insight.transAxes
)

# ── Títulos ────────────────────────────────────────────────────────────────────
fig.suptitle(
    'ECDF — Función de Distribución Acumulada Empírica\n'
    'Variables Cuantitativas por Diagnóstico Cardíaco',
    fontsize=16, fontweight='bold',
    color=COLOR_NAVY, y=1.01
)
fig.text(
    0.5, 0.9485,
    'Dataset: Heart Disease UCI · n=303  |  '
    '● Punto = mediana  |  '
    'Líneas punteadas = P25, P50, P75',
    ha='center', fontsize=9, color=COLOR_GRAY
)
fig.text(0.02, 0.005, 'MANUEL MERINO · by SciTeX',
         fontsize=8, color=COLOR_NAVY,
         alpha=0.5, fontweight='bold')
fig.text(0.98, 0.005, '#PensarConDatos',
         fontsize=8, color=COLOR_ACCENT, ha='right')

plt.tight_layout(rect=[0, 0.02, 1, 0.98])
plt.savefig('g12_ecdf.svg',
            bbox_inches='tight',
            facecolor=COLOR_BG, format='svg')
plt.savefig('g12_ecdf.png',
            dpi=150, bbox_inches='tight',
            facecolor=COLOR_BG)
print("✓ G12 ECDF guardado")
plt.show()
# Out:
# ✓ G12 ECDF guardado

# %% [markdown]
# <div style="background: linear-gradient(135deg, #27295a 0%, #304b9a 100%);
#             padding: 20px 32px; border-radius: 10px; margin-top: 32px;
#             display: flex; justify-content: space-between;
#             align-items: center; flex-wrap: wrap; gap: 12px;">
#   <div>
#     <div style="color: white; font-size: 14px; font-weight: 700;
#                 font-family: sans-serif;">MANUEL MERINO · by SciTeX</div>
#     <div style="color: #85B7EB; font-size: 11px; font-family: sans-serif;
#                 margin-top: 2px;">
#       Aprende a pensar con datos. No solo a usar herramientas.
#     </div>
#   </div>
#   <div style="display: flex; gap: 8px;">
#     <a href="https://www.linkedin.com/company/scitexoficial"
#        style="background: rgba(133,183,235,0.2); color: #85B7EB;
#               padding: 6px 14px; border-radius: 20px; font-size: 11px;
#               font-family: sans-serif; text-decoration: none;
#               font-weight: 600;">LinkedIn SciTeX</a>
#     <a href="https://github.com/scitex-oficial/eda-heart-disease/tree/main"
#        style="background: rgba(133,183,235,0.2); color: #85B7EB;
#               padding: 6px 14px; border-radius: 20px; font-size: 11px;
#               font-family: sans-serif; text-decoration: none;
#               font-weight: 600;">GitHub</a>
#   </div>
# </div>
